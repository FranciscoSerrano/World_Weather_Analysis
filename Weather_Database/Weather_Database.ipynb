# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city id is unique, then we will add it to the cities list
    if city not in cities:
            cities.append(city)
            
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 751

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c97e4af4cd7b576cecefa545a86ba9de

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1 
set_count = 1

# loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_description})
        
# If an error is experienced, skip the city
    except:
            print("City not found. Skipping...")
            pass
        
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | namibe
# Processing Record 5 of Set 1 | tabou
# Processing Record 6 of Set 1 | trincomalee
# Processing Record 7 of Set 1 | cabo san lucas
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | boa vista
# Processing Record 13 of Set 1 | guerrero negro
# Processing Record 14 of Set 1 | saskylakh
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | jacqueville
# Processing Record 17 of Set 1 | sao filipe
# Processing Record 18 of Set 1 | coihaique
# Processing Record 19 of Set 1 | constitucion
# Processing Record 20 of Set 1 | sioux lookout
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | luanda
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | adrar
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | ilulissat
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | pathein
# Processing Record 30 of Set 1 | muravlenko
# Processing Record 31 of Set 1 | tuatapere
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | isangel
# Processing Record 34 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | hasaki
# Processing Record 38 of Set 1 | nemuro
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | viedma
# Processing Record 41 of Set 1 | lompoc
# Processing Record 42 of Set 1 | jalu
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 1 | naze
# Processing Record 47 of Set 1 | tilichiki
# Processing Record 48 of Set 1 | healdsburg
# Processing Record 49 of Set 1 | armacao dos buzios
# City not found. Skipping...
# Processing Record 50 of Set 1 | bull savanna
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | saint-philippe
# Processing Record 5 of Set 2 | manta
# Processing Record 6 of Set 2 | jurm
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | mvuma
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | havre-saint-pierre
# Processing Record 14 of Set 2 | graaff-reinet
# Processing Record 15 of Set 2 | inuvik
# Processing Record 16 of Set 2 | rikitea
# Processing Record 17 of Set 2 | longyearbyen
# Processing Record 18 of Set 2 | pallasovka
# Processing Record 19 of Set 2 | kupang
# Processing Record 20 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 2 | marystown
# Processing Record 22 of Set 2 | bang sao thong
# Processing Record 23 of Set 2 | margate
# Processing Record 24 of Set 2 | lorengau
# Processing Record 25 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 2 | cockburn town
# Processing Record 27 of Set 2 | wanganui
# Processing Record 28 of Set 2 | saldanha
# Processing Record 29 of Set 2 | dillon
# Processing Record 30 of Set 2 | vestmannaeyjar
# Processing Record 31 of Set 2 | davenport
# Processing Record 32 of Set 2 | kaitangata
# Processing Record 33 of Set 2 | henties bay
# Processing Record 34 of Set 2 | fortuna
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | marfino
# Processing Record 37 of Set 2 | san quintin
# Processing Record 38 of Set 2 | port shepstone
# Processing Record 39 of Set 2 | megion
# Processing Record 40 of Set 2 | iqaluit
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | krasnoselkup
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 2 | yellowknife
# Processing Record 46 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 2 | clyde river
# Processing Record 48 of Set 2 | aswan
# Processing Record 49 of Set 2 | ushuaia
# Processing Record 50 of Set 2 | flinders
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 3 | khasan
# Processing Record 4 of Set 3 | egvekinot
# Processing Record 5 of Set 3 | asht
# City not found. Skipping...
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | castro
# Processing Record 8 of Set 3 | chokurdakh
# Processing Record 9 of Set 3 | hithadhoo
# Processing Record 10 of Set 3 | acapulco
# Processing Record 11 of Set 3 | wasilla
# Processing Record 12 of Set 3 | kpalime
# Processing Record 13 of Set 3 | luderitz
# Processing Record 14 of Set 3 | hambantota
# Processing Record 15 of Set 3 | saint george
# Processing Record 16 of Set 3 | emba
# Processing Record 17 of Set 3 | zhangye
# Processing Record 18 of Set 3 | vostok
# Processing Record 19 of Set 3 | mackay
# Processing Record 20 of Set 3 | bandarbeyla
# Processing Record 21 of Set 3 | fukue
# Processing Record 22 of Set 3 | hermanus
# Processing Record 23 of Set 3 | sinnamary
# Processing Record 24 of Set 3 | acarau
# Processing Record 25 of Set 3 | leh
# Processing Record 26 of Set 3 | bathsheba
# Processing Record 27 of Set 3 | arrecife
# Processing Record 28 of Set 3 | lucea
# Processing Record 29 of Set 3 | puyang
# Processing Record 30 of Set 3 | klaksvik
# Processing Record 31 of Set 3 | vao
# Processing Record 32 of Set 3 | poum
# Processing Record 33 of Set 3 | shetpe
# Processing Record 34 of Set 3 | matara
# Processing Record 35 of Set 3 | tashtyp
# Processing Record 36 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 3 | dongsheng
# Processing Record 38 of Set 3 | tazmalt
# Processing Record 39 of Set 3 | lagoa
# Processing Record 40 of Set 3 | vestmanna
# Processing Record 41 of Set 3 | topeka
# Processing Record 42 of Set 3 | terrace
# Processing Record 43 of Set 3 | avera
# Processing Record 44 of Set 3 | ibaiti
# Processing Record 45 of Set 3 | port blair
# Processing Record 46 of Set 3 | dovers
# Processing Record 47 of Set 3 | desert hot springs
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | pozo colorado
# Processing Record 50 of Set 3 | requena
# Processing Record 1 of Set 4 | cortland
# Processing Record 2 of Set 4 | bereznik
# Processing Record 3 of Set 4 | fenoarivo
# Processing Record 4 of Set 4 | rawlins
# Processing Record 5 of Set 4 | hilo
# Processing Record 6 of Set 4 | touros
# Processing Record 7 of Set 4 | angoram
# Processing Record 8 of Set 4 | tuktoyaktuk
# Processing Record 9 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 4 | touba
# Processing Record 11 of Set 4 | barra do garcas
# Processing Record 12 of Set 4 | mukhanovo
# City not found. Skipping...
# Processing Record 13 of Set 4 | mariental
# Processing Record 14 of Set 4 | hun
# Processing Record 15 of Set 4 | talaya
# Processing Record 16 of Set 4 | hovd
# Processing Record 17 of Set 4 | kargil
# Processing Record 18 of Set 4 | chapais
# Processing Record 19 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 4 | cherskiy
# Processing Record 21 of Set 4 | aasiaat
# Processing Record 22 of Set 4 | awbari
# Processing Record 23 of Set 4 | san joaquin
# Processing Record 24 of Set 4 | lewiston
# Processing Record 25 of Set 4 | mumbwa
# Processing Record 26 of Set 4 | morondava
# Processing Record 27 of Set 4 | bowen
# Processing Record 28 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 4 | pevek
# Processing Record 30 of Set 4 | connersville
# Processing Record 31 of Set 4 | channel-port aux basques
# Processing Record 32 of Set 4 | bani walid
# Processing Record 33 of Set 4 | conceicao do araguaia
# Processing Record 34 of Set 4 | bambous virieux
# Processing Record 35 of Set 4 | anadyr
# Processing Record 36 of Set 4 | upernavik
# Processing Record 37 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 4 | narsaq
# Processing Record 39 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 40 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 4 | norman wells
# Processing Record 42 of Set 4 | sidrolandia
# Processing Record 43 of Set 4 | san pedro
# Processing Record 44 of Set 4 | albany
# Processing Record 45 of Set 4 | baghdad
# Processing Record 46 of Set 4 | arraial do cabo
# Processing Record 47 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 4 | itigi
# Processing Record 49 of Set 4 | inverell
# Processing Record 50 of Set 4 | savonlinna
# Processing Record 1 of Set 5 | turukhansk
# Processing Record 2 of Set 5 | bombay
# Processing Record 3 of Set 5 | ambagarh chauki
# Processing Record 4 of Set 5 | teguise
# Processing Record 5 of Set 5 | georgetown
# Processing Record 6 of Set 5 | iranshahr
# Processing Record 7 of Set 5 | talnakh
# Processing Record 8 of Set 5 | chuy
# Processing Record 9 of Set 5 | great yarmouth
# Processing Record 10 of Set 5 | souillac
# Processing Record 11 of Set 5 | mount isa
# Processing Record 12 of Set 5 | dapaong
# Processing Record 13 of Set 5 | dossor
# Processing Record 14 of Set 5 | severo-kurilsk
# Processing Record 15 of Set 5 | hualmay
# Processing Record 16 of Set 5 | abu samrah
# Processing Record 17 of Set 5 | sylva
# Processing Record 18 of Set 5 | belaya gora
# Processing Record 19 of Set 5 | vila franca do campo
# Processing Record 20 of Set 5 | portland
# Processing Record 21 of Set 5 | skjervoy
# Processing Record 22 of Set 5 | anloga
# Processing Record 23 of Set 5 | codrington
# Processing Record 24 of Set 5 | lokosovo
# Processing Record 25 of Set 5 | bethanien
# Processing Record 26 of Set 5 | burica
# City not found. Skipping...
# Processing Record 27 of Set 5 | northam
# Processing Record 28 of Set 5 | saint-pierre
# Processing Record 29 of Set 5 | nikolskoye
# Processing Record 30 of Set 5 | hami
# Processing Record 31 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 32 of Set 5 | tibu
# Processing Record 33 of Set 5 | maniitsoq
# Processing Record 34 of Set 5 | lujan
# Processing Record 35 of Set 5 | malaya serdoba
# Processing Record 36 of Set 5 | kropotkin
# Processing Record 37 of Set 5 | geraldton
# Processing Record 38 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 5 | vila velha
# Processing Record 40 of Set 5 | irbil
# Processing Record 41 of Set 5 | khartoum
# Processing Record 42 of Set 5 | torbay
# Processing Record 43 of Set 5 | nizhniy kuranakh
# Processing Record 44 of Set 5 | korla
# Processing Record 45 of Set 5 | puerto penasco
# Processing Record 46 of Set 5 | roald
# Processing Record 47 of Set 5 | aras
# Processing Record 48 of Set 5 | ahipara
# Processing Record 49 of Set 5 | zunyi
# Processing Record 50 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 6 | sitka
# Processing Record 2 of Set 6 | brandon
# Processing Record 3 of Set 6 | la palma
# Processing Record 4 of Set 6 | bengkulu
# Processing Record 5 of Set 6 | panama city
# Processing Record 6 of Set 6 | el alto
# Processing Record 7 of Set 6 | severodvinsk
# Processing Record 8 of Set 6 | juneau
# Processing Record 9 of Set 6 | santa barbara
# Processing Record 10 of Set 6 | oum hadjer
# Processing Record 11 of Set 6 | ballina
# Processing Record 12 of Set 6 | husavik
# Processing Record 13 of Set 6 | spassk-ryazanskiy
# Processing Record 14 of Set 6 | new norfolk
# Processing Record 15 of Set 6 | southbridge
# Processing Record 16 of Set 6 | bilibino
# Processing Record 17 of Set 6 | wanning
# Processing Record 18 of Set 6 | funtua
# Processing Record 19 of Set 6 | gillette
# Processing Record 20 of Set 6 | pangnirtung
# Processing Record 21 of Set 6 | awjilah
# Processing Record 22 of Set 6 | utiel
# Processing Record 23 of Set 6 | talcahuano
# Processing Record 24 of Set 6 | victoria
# Processing Record 25 of Set 6 | grand gaube
# Processing Record 26 of Set 6 | poya
# Processing Record 27 of Set 6 | bethel
# Processing Record 28 of Set 6 | effingham
# Processing Record 29 of Set 6 | haines junction
# Processing Record 30 of Set 6 | namtsy
# Processing Record 31 of Set 6 | ternate
# Processing Record 32 of Set 6 | dingle
# Processing Record 33 of Set 6 | hobyo
# Processing Record 34 of Set 6 | werota
# Processing Record 35 of Set 6 | sola
# Processing Record 36 of Set 6 | san carlos
# Processing Record 37 of Set 6 | nipawin
# Processing Record 38 of Set 6 | ikom
# Processing Record 39 of Set 6 | buraydah
# Processing Record 40 of Set 6 | causapscal
# Processing Record 41 of Set 6 | sao joao da barra
# Processing Record 42 of Set 6 | magadan
# Processing Record 43 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 44 of Set 6 | troitsko-pechorsk
# Processing Record 45 of Set 6 | sao gabriel da cachoeira
# Processing Record 46 of Set 6 | ahuimanu
# Processing Record 47 of Set 6 | ulaangom
# Processing Record 48 of Set 6 | san patricio
# Processing Record 49 of Set 6 | tautira
# Processing Record 50 of Set 6 | broome
# Processing Record 1 of Set 7 | provideniya
# Processing Record 2 of Set 7 | umm lajj
# Processing Record 3 of Set 7 | kruisfontein
# Processing Record 4 of Set 7 | tiznit
# Processing Record 5 of Set 7 | sar-e pul
# Processing Record 6 of Set 7 | half moon bay
# Processing Record 7 of Set 7 | newport
# Processing Record 8 of Set 7 | koumac
# Processing Record 9 of Set 7 | palmer
# Processing Record 10 of Set 7 | puerto escondido
# Processing Record 11 of Set 7 | ancud
# Processing Record 12 of Set 7 | bogo
# Processing Record 13 of Set 7 | bud
# Processing Record 14 of Set 7 | zyryanovsk
# Processing Record 15 of Set 7 | kodiak
# Processing Record 16 of Set 7 | padang
# Processing Record 17 of Set 7 | novobirilyussy
# Processing Record 18 of Set 7 | shasta lake
# Processing Record 19 of Set 7 | male
# Processing Record 20 of Set 7 | yulara
# Processing Record 21 of Set 7 | hvammstangi
# City not found. Skipping...
# Processing Record 22 of Set 7 | tiksi
# Processing Record 23 of Set 7 | owerri
# Processing Record 24 of Set 7 | bolshaya murta
# City not found. Skipping...
# Processing Record 25 of Set 7 | kuching
# Processing Record 26 of Set 7 | lazaro cardenas
# Processing Record 27 of Set 7 | maceio
# Processing Record 28 of Set 7 | dudinka
# Processing Record 29 of Set 7 | miles city
# Processing Record 30 of Set 7 | osakarovka
# Processing Record 31 of Set 7 | rena
# Processing Record 32 of Set 7 | alice springs
# Processing Record 33 of Set 7 | nenjiang
# Processing Record 34 of Set 7 | yenagoa
# Processing Record 35 of Set 7 | port macquarie
# Processing Record 36 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 7 | nizhniy baskunchak
# Processing Record 38 of Set 7 | shingu
# Processing Record 39 of Set 7 | lavrentiya
# Processing Record 40 of Set 7 | sur
# Processing Record 41 of Set 7 | mansa
# Processing Record 42 of Set 7 | port hedland
# Processing Record 43 of Set 7 | ipeti
# City not found. Skipping...
# Processing Record 44 of Set 7 | dzaoudzi
# Processing Record 45 of Set 7 | skelleftea
# Processing Record 46 of Set 7 | beloha
# Processing Record 47 of Set 7 | alma
# Processing Record 48 of Set 7 | sept-iles
# Processing Record 49 of Set 7 | kavieng
# Processing Record 50 of Set 7 | belmonte
# Processing Record 1 of Set 8 | xinzhou
# Processing Record 2 of Set 8 | caucasia
# Processing Record 3 of Set 8 | kirakira
# Processing Record 4 of Set 8 | san jeronimo
# Processing Record 5 of Set 8 | quatre cocos
# Processing Record 6 of Set 8 | charters towers
# Processing Record 7 of Set 8 | san andres
# Processing Record 8 of Set 8 | carmen
# Processing Record 9 of Set 8 | okha
# Processing Record 10 of Set 8 | klyuchi
# Processing Record 11 of Set 8 | hurghada
# Processing Record 12 of Set 8 | bentiu
# Processing Record 13 of Set 8 | the valley
# Processing Record 14 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 8 | inta
# Processing Record 16 of Set 8 | igarka
# Processing Record 17 of Set 8 | dasoguz
# Processing Record 18 of Set 8 | ravar
# Processing Record 19 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 8 | tura
# Processing Record 21 of Set 8 | marsa matruh
# Processing Record 22 of Set 8 | komsomolskiy
# Processing Record 23 of Set 8 | play cu
# City not found. Skipping...
# Processing Record 24 of Set 8 | santa flavia
# Processing Record 25 of Set 8 | auki
# Processing Record 26 of Set 8 | te anau
# Processing Record 27 of Set 8 | asau
# Processing Record 28 of Set 8 | santa maria
# Processing Record 29 of Set 8 | saint-georges
# Processing Record 30 of Set 8 | college station
# Processing Record 31 of Set 8 | faanui
# Processing Record 32 of Set 8 | monticello
# Processing Record 33 of Set 8 | acajutla
# Processing Record 34 of Set 8 | roura
# Processing Record 35 of Set 8 | san carlos de bariloche
# Processing Record 36 of Set 8 | santa elena
# Processing Record 37 of Set 8 | gat
# Processing Record 38 of Set 8 | valparaiso
# Processing Record 39 of Set 8 | pingliang
# Processing Record 40 of Set 8 | kizhinga
# Processing Record 41 of Set 8 | chicama
# Processing Record 42 of Set 8 | gouyave
# Processing Record 43 of Set 8 | berlevag
# Processing Record 44 of Set 8 | albanel
# Processing Record 45 of Set 8 | kjollefjord
# Processing Record 46 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 8 | ati
# Processing Record 48 of Set 8 | kotli loharan
# Processing Record 49 of Set 8 | krasnogorsk
# Processing Record 50 of Set 8 | pereira barreto
# Processing Record 1 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 3 of Set 9 | mithimna
# City not found. Skipping...
# Processing Record 4 of Set 9 | itarema
# Processing Record 5 of Set 9 | beohari
# Processing Record 6 of Set 9 | pacific grove
# Processing Record 7 of Set 9 | taft
# Processing Record 8 of Set 9 | consolacion del sur
# Processing Record 9 of Set 9 | bilecik
# Processing Record 10 of Set 9 | cam pha
# City not found. Skipping...
# Processing Record 11 of Set 9 | tiarei
# Processing Record 12 of Set 9 | paoua
# Processing Record 13 of Set 9 | wampusirpi
# City not found. Skipping...
# Processing Record 14 of Set 9 | artemovsk
# Processing Record 15 of Set 9 | hofn
# Processing Record 16 of Set 9 | pitkyaranta
# Processing Record 17 of Set 9 | bayburt
# Processing Record 18 of Set 9 | mian channun
# Processing Record 19 of Set 9 | atar
# Processing Record 20 of Set 9 | sayalgudi
# City not found. Skipping...
# Processing Record 21 of Set 9 | esperance
# Processing Record 22 of Set 9 | rio claro
# Processing Record 23 of Set 9 | lasa
# Processing Record 24 of Set 9 | tabulbah
# City not found. Skipping...
# Processing Record 25 of Set 9 | ishigaki
# Processing Record 26 of Set 9 | humberto de campos
# Processing Record 27 of Set 9 | orlik
# Processing Record 28 of Set 9 | mujiayingzi
# Processing Record 29 of Set 9 | nome
# Processing Record 30 of Set 9 | obo
# Processing Record 31 of Set 9 | son la
# Processing Record 32 of Set 9 | bandar
# Processing Record 33 of Set 9 | launceston
# Processing Record 34 of Set 9 | pochutla
# Processing Record 35 of Set 9 | miri
# Processing Record 36 of Set 9 | jumla
# Processing Record 37 of Set 9 | saint-augustin
# Processing Record 38 of Set 9 | englewood
# Processing Record 39 of Set 9 | evensk
# Processing Record 40 of Set 9 | sungaipenuh
# Processing Record 41 of Set 9 | coari
# Processing Record 42 of Set 9 | la asuncion
# Processing Record 43 of Set 9 | kambia
# Processing Record 44 of Set 9 | mongoumba
# Processing Record 45 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 46 of Set 9 | jevnaker
# Processing Record 47 of Set 9 | airai
# Processing Record 48 of Set 9 | ciudad bolivar
# Processing Record 49 of Set 9 | bourail
# Processing Record 50 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 1 of Set 10 | eureka
# Processing Record 2 of Set 10 | coahuayana
# Processing Record 3 of Set 10 | harper
# Processing Record 4 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 5 of Set 10 | moose factory
# Processing Record 6 of Set 10 | boyuibe
# Processing Record 7 of Set 10 | faya
# Processing Record 8 of Set 10 | fethiye
# Processing Record 9 of Set 10 | carmo do rio claro
# Processing Record 10 of Set 10 | adeje
# Processing Record 11 of Set 10 | babushkin
# Processing Record 12 of Set 10 | mitsamiouli
# Processing Record 13 of Set 10 | seoul
# Processing Record 14 of Set 10 | port-gentil
# Processing Record 15 of Set 10 | comodoro rivadavia
# Processing Record 16 of Set 10 | kismayo
# Processing Record 17 of Set 10 | betsiamites
# Processing Record 18 of Set 10 | ushtobe
# Processing Record 19 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 20 of Set 10 | port lincoln
# Processing Record 21 of Set 10 | kaeo
# Processing Record 22 of Set 10 | ryotsu
# Processing Record 23 of Set 10 | rimbey
# Processing Record 24 of Set 10 | honiara
# Processing Record 25 of Set 10 | nouadhibou
# Processing Record 26 of Set 10 | maridi
# Processing Record 27 of Set 10 | san matias
# Processing Record 28 of Set 10 | amapa
# Processing Record 29 of Set 10 | atambua
# Processing Record 30 of Set 10 | nacala
# Processing Record 31 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 10 | axim
# Processing Record 33 of Set 10 | cooma
# Processing Record 34 of Set 10 | bolshoye bunkovo
# City not found. Skipping...
# Processing Record 35 of Set 10 | san rafael del sur
# Processing Record 36 of Set 10 | kimbe
# Processing Record 37 of Set 10 | salalah
# Processing Record 38 of Set 10 | takaka
# Processing Record 39 of Set 10 | rafaela
# Processing Record 40 of Set 10 | kysyl-syr
# Processing Record 41 of Set 10 | san pedro de macoris
# Processing Record 42 of Set 10 | lisakovsk
# Processing Record 43 of Set 10 | nanyang
# Processing Record 44 of Set 10 | atlantic city
# Processing Record 45 of Set 10 | belyy yar
# Processing Record 46 of Set 10 | xapuri
# Processing Record 47 of Set 10 | dolinsk
# Processing Record 48 of Set 10 | stutterheim
# Processing Record 49 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 10 | waipawa
# Processing Record 1 of Set 11 | qingdao
# Processing Record 2 of Set 11 | richards bay
# Processing Record 3 of Set 11 | meadow lake
# Processing Record 4 of Set 11 | mogadishu
# Processing Record 5 of Set 11 | laguna
# Processing Record 6 of Set 11 | isabela
# Processing Record 7 of Set 11 | platanos
# Processing Record 8 of Set 11 | denpasar
# Processing Record 9 of Set 11 | taal
# Processing Record 10 of Set 11 | yurga
# Processing Record 11 of Set 11 | marsh harbour
# Processing Record 12 of Set 11 | scarborough
# Processing Record 13 of Set 11 | batagay-alyta
# Processing Record 14 of Set 11 | kharp
# Processing Record 15 of Set 11 | dukat
# Processing Record 16 of Set 11 | grootfontein
# Processing Record 17 of Set 11 | vardo
# Processing Record 18 of Set 11 | washington
# Processing Record 19 of Set 11 | tarko-sale
# Processing Record 20 of Set 11 | urucui
# Processing Record 21 of Set 11 | kloulklubed
# Processing Record 22 of Set 11 | jackson
# Processing Record 23 of Set 11 | bang saphan
# Processing Record 24 of Set 11 | beringovskiy
# Processing Record 25 of Set 11 | yumen
# Processing Record 26 of Set 11 | taoudenni
# Processing Record 27 of Set 11 | moussoro
# Processing Record 28 of Set 11 | bontang
# Processing Record 29 of Set 11 | kiunga
# Processing Record 30 of Set 11 | vanavara
# Processing Record 31 of Set 11 | zakamensk
# Processing Record 32 of Set 11 | naugarzan
# City not found. Skipping...
# Processing Record 33 of Set 11 | guadalajara
# Processing Record 34 of Set 11 | ende
# Processing Record 35 of Set 11 | yibin
# Processing Record 36 of Set 11 | sorland
# Processing Record 37 of Set 11 | goderich
# Processing Record 38 of Set 11 | arlit
# Processing Record 39 of Set 11 | chadiza
# Processing Record 40 of Set 11 | wukari
# Processing Record 41 of Set 11 | xuddur
# Processing Record 42 of Set 11 | katsuura
# Processing Record 43 of Set 11 | praia da vitoria
# Processing Record 44 of Set 11 | leningradskiy
# Processing Record 45 of Set 11 | ulagan
# Processing Record 46 of Set 11 | lavumisa
# Processing Record 47 of Set 11 | tigzirt
# Processing Record 48 of Set 11 | ilinskaya
# Processing Record 49 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 50 of Set 11 | bandarban
# Processing Record 1 of Set 12 | nanortalik
# Processing Record 2 of Set 12 | mizdah
# Processing Record 3 of Set 12 | atyrau
# Processing Record 4 of Set 12 | puerto carreno
# Processing Record 5 of Set 12 | alamosa
# Processing Record 6 of Set 12 | agadez
# Processing Record 7 of Set 12 | riverton
# Processing Record 8 of Set 12 | tres arroyos
# Processing Record 9 of Set 12 | warmbad
# Processing Record 10 of Set 12 | tshikapa
# Processing Record 11 of Set 12 | quimper
# Processing Record 12 of Set 12 | aklavik
# Processing Record 13 of Set 12 | mabaruma
# Processing Record 14 of Set 12 | rocha
# Processing Record 15 of Set 12 | patacamaya
# Processing Record 16 of Set 12 | deniliquin
# Processing Record 17 of Set 12 | hellvik
# Processing Record 18 of Set 12 | havoysund
# Processing Record 19 of Set 12 | dormidontovka
# Processing Record 20 of Set 12 | shenjiamen
# Processing Record 21 of Set 12 | santa marta
# Processing Record 22 of Set 12 | nalut
# Processing Record 23 of Set 12 | zeya
# Processing Record 24 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 12 | campbell river
# Processing Record 26 of Set 12 | matagami
# Processing Record 27 of Set 12 | pandan
# Processing Record 28 of Set 12 | kasongo-lunda
# Processing Record 29 of Set 12 | tessalit
# Processing Record 30 of Set 12 | namatanai
# Processing Record 31 of Set 12 | fremont
# Processing Record 32 of Set 12 | pisco
# Processing Record 33 of Set 12 | ostrovnoy
# Processing Record 34 of Set 12 | sao paulo de olivenca
# Processing Record 35 of Set 12 | vaitape
# Processing Record 36 of Set 12 | fomboni
# Processing Record 37 of Set 12 | sabang
# Processing Record 38 of Set 12 | panjab
# Processing Record 39 of Set 12 | biltine
# Processing Record 40 of Set 12 | lamont
# Processing Record 41 of Set 12 | damghan
# Processing Record 42 of Set 12 | ponta do sol
# Processing Record 43 of Set 12 | alofi
# Processing Record 44 of Set 12 | huaraz
# Processing Record 45 of Set 12 | kousseri
# Processing Record 46 of Set 12 | shubarshi
# Processing Record 47 of Set 12 | ribas do rio pardo
# Processing Record 48 of Set 12 | kununurra
# Processing Record 49 of Set 12 | ibipeba
# Processing Record 50 of Set 12 | porto novo
# Processing Record 1 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 2 of Set 13 | abengourou
# Processing Record 3 of Set 13 | mirabad
# Processing Record 4 of Set 13 | sambava
# Processing Record 5 of Set 13 | kwinana
# Processing Record 6 of Set 13 | luganville
# Processing Record 7 of Set 13 | faizpur
# Processing Record 8 of Set 13 | batie
# Processing Record 9 of Set 13 | teya
# Processing Record 10 of Set 13 | wajir
# Processing Record 11 of Set 13 | hay river
# Processing Record 12 of Set 13 | manakara
# Processing Record 13 of Set 13 | baykit
# Processing Record 14 of Set 13 | bonavista
# Processing Record 15 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 16 of Set 13 | oranjemund
# Processing Record 17 of Set 13 | baker city
# Processing Record 18 of Set 13 | kieta
# Processing Record 19 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 20 of Set 13 | ayagoz
# Processing Record 21 of Set 13 | havelock
# Processing Record 22 of Set 13 | kulpahar
# Processing Record 23 of Set 13 | otradnoye
# Processing Record 24 of Set 13 | mahuva
# Processing Record 25 of Set 13 | banikoara
# Processing Record 26 of Set 13 | barra patuca
# Processing Record 27 of Set 13 | mehamn
# Processing Record 28 of Set 13 | weinheim
# Processing Record 29 of Set 13 | qingyuan
# Processing Record 30 of Set 13 | rathenow
# Processing Record 31 of Set 13 | manjeshwar
# Processing Record 32 of Set 13 | port augusta
# Processing Record 33 of Set 13 | whitehorse
# Processing Record 34 of Set 13 | zhigansk
# Processing Record 35 of Set 13 | bama
# Processing Record 36 of Set 13 | kabo
# Processing Record 37 of Set 13 | saint-francois
# Processing Record 38 of Set 13 | rio grande
# Processing Record 39 of Set 13 | bismarck
# Processing Record 40 of Set 13 | sanski most
# Processing Record 41 of Set 13 | noyabrsk
# Processing Record 42 of Set 13 | simoes
# Processing Record 43 of Set 13 | chanika
# Processing Record 44 of Set 13 | sao jose da coroa grande
# Processing Record 45 of Set 13 | egersund
# Processing Record 46 of Set 13 | hall
# Processing Record 47 of Set 13 | sao felix do xingu
# Processing Record 48 of Set 13 | xanxere
# Processing Record 49 of Set 13 | salitral
# Processing Record 50 of Set 13 | caravelas
# Processing Record 1 of Set 14 | flin flon
# Processing Record 2 of Set 14 | ayr
# Processing Record 3 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 14 | aykhal
# Processing Record 5 of Set 14 | erice
# Processing Record 6 of Set 14 | priiskovyy
# Processing Record 7 of Set 14 | terra santa
# Processing Record 8 of Set 14 | port hardy
# Processing Record 9 of Set 14 | hirara
# Processing Record 10 of Set 14 | bendigo
# Processing Record 11 of Set 14 | bubaque
# Processing Record 12 of Set 14 | jalingo
# Processing Record 13 of Set 14 | shimoda
# Processing Record 14 of Set 14 | chipinge
# Processing Record 15 of Set 14 | xining
# Processing Record 16 of Set 14 | manga
# Processing Record 17 of Set 14 | lamu
# Processing Record 18 of Set 14 | puerto del rosario
# Processing Record 19 of Set 14 | monte patria
# Processing Record 20 of Set 14 | humaita
# Processing Record 21 of Set 14 | itupeva
# Processing Record 22 of Set 14 | chunskiy
# Processing Record 23 of Set 14 | deputatskiy
# Processing Record 24 of Set 14 | houston
# Processing Record 25 of Set 14 | hope
# Processing Record 26 of Set 14 | koboldo
# City not found. Skipping...
# Processing Record 27 of Set 14 | kilosa
# Processing Record 28 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 14 | maldonado
# Processing Record 30 of Set 14 | monteagudo
# Processing Record 31 of Set 14 | nong khai
# Processing Record 32 of Set 14 | yaan
# Processing Record 33 of Set 14 | bonfim
# Processing Record 34 of Set 14 | aleppo
# Processing Record 35 of Set 14 | kavaratti
# Processing Record 36 of Set 14 | navan
# Processing Record 37 of Set 14 | eyl
# Processing Record 38 of Set 14 | puerto leguizamo
# Processing Record 39 of Set 14 | butte
# Processing Record 40 of Set 14 | dax
# Processing Record 41 of Set 14 | gamba
# Processing Record 42 of Set 14 | centralia
# Processing Record 43 of Set 14 | polignano a mare
# Processing Record 44 of Set 14 | sapa
# Processing Record 45 of Set 14 | subate
# Processing Record 46 of Set 14 | salinopolis
# Processing Record 47 of Set 14 | daud khel
# Processing Record 48 of Set 14 | yeppoon
# Processing Record 49 of Set 14 | oksfjord
# Processing Record 50 of Set 14 | payo
# Processing Record 1 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 15 | imeni poliny osipenko
# Processing Record 3 of Set 15 | kemin
# Processing Record 4 of Set 15 | atbasar
# Processing Record 5 of Set 15 | reims
# Processing Record 6 of Set 15 | vilhena
# Processing Record 7 of Set 15 | griffith
# Processing Record 8 of Set 15 | maragogi
# Processing Record 9 of Set 15 | clonakilty
# Processing Record 10 of Set 15 | mathathane
# Processing Record 11 of Set 15 | loandjili
# Processing Record 12 of Set 15 | cayenne
# Processing Record 13 of Set 15 | badiraguato
# Processing Record 14 of Set 15 | mwene-ditu
# Processing Record 15 of Set 15 | linxia
# Processing Record 16 of Set 15 | guiberoua
# Processing Record 17 of Set 15 | necochea
# Processing Record 18 of Set 15 | odweyne
# Processing Record 19 of Set 15 | jilin
# Processing Record 20 of Set 15 | yabelo
# Processing Record 21 of Set 15 | altay
# Processing Record 22 of Set 15 | bereslavka
# Processing Record 23 of Set 15 | grindavik
# Processing Record 24 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 25 of Set 15 | krasnyy chikoy
# Processing Record 26 of Set 15 | glenwood springs
# Processing Record 27 of Set 15 | wajima
# Processing Record 28 of Set 15 | green river
# Processing Record 29 of Set 15 | hong gai
# Processing Record 30 of Set 15 | matamba
# Processing Record 31 of Set 15 | hit
# Processing Record 32 of Set 15 | kinsale
# Processing Record 33 of Set 15 | wa
# City not found. Skipping...
# Processing Record 34 of Set 15 | sijunjung
# Processing Record 35 of Set 15 | champerico
# Processing Record 36 of Set 15 | kholodnyy
# Processing Record 37 of Set 15 | manado
# Processing Record 38 of Set 15 | salinas
# Processing Record 39 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 15 | vilyuysk
# Processing Record 41 of Set 15 | kahului
# Processing Record 42 of Set 15 | polyarnyy
# Processing Record 43 of Set 15 | mount gambier
# Processing Record 44 of Set 15 | tongren
# Processing Record 45 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 15 | vysokogornyy
# Processing Record 48 of Set 15 | abnub
# Processing Record 49 of Set 15 | la macarena
# Processing Record 50 of Set 15 | raga
# Processing Record 1 of Set 16 | vitim
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': 112.56, 'lat': 59.45},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 60.62,
#   'feels_like': 58.32,
#   'temp_min': 60.62,
#   'temp_max': 60.62,
#   'pressure': 1013,
#   'humidity': 64,
#   'sea_level': 1013,
#   'grnd_level': 989},
#  'visibility': 10000,
#  'wind': {'speed': 3.49, 'deg': 195},
#  'clouds': {'all': 100},
#  'dt': 1598633632,
#  'sys': {'country': 'RU', 'sunrise': 1598649571, 'sunset': 1598701339},
#  'timezone': 32400,
#  'id': 2013375,
#  'name': 'Vitim',
#  'cod': 200}

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0           Bluff -46.60  168.33     45.00        72          36       11.01
# 1        Thompson  55.74  -97.86     51.80        93          90        6.93
# 2     Port Alfred -33.59   26.89     59.61        68           0       10.96
# 3          Namibe -15.20   12.15     61.86        80          25       11.99
# 4           Tabou   4.42   -7.35     78.06        81          94       12.39
# 5     Trincomalee   8.57   81.23     82.02        71          82        8.30
# 6  Cabo San Lucas  22.89 -109.91     78.01        88          90        2.24
# 7            Lebu -37.62  -73.65     50.04        93         100       20.29
# 8      Butaritari   3.07  172.79     82.63        72          99       13.11
# 9        Khatanga  71.97  102.50     55.38        58          69        5.73
#
#   Country Current Description
# 0      NZ    scattered clouds
# 1      CA     overcast clouds
# 2      ZA           clear sky
# 3      AO    scattered clouds
# 4      CI     overcast clouds
# 5      LK       broken clouds
# 6      MX     overcast clouds
# 7      CL     overcast clouds
# 8      KI     overcast clouds
# 9      RU       broken clouds

# %%
# Create the output file (CSV)
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
